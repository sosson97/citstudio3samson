# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master('local[*]').appName('SparkSQL_Review').getOrCreate()
df = spark.read.format("com.databricks.spark.csv").option("header", "true").option("inferSchema", "true").load('D:/OneDrive\OneDrive - postech.ac.kr/2019 Spring/창의설계 3/Archive/real data/Fangraphs 1980-2017 5ys.csv')
df.printSchema()

columns = ['Season', 'W', 'L', 'G', 'GS', 'IP', 'Kd9', 'BBd9', 'HRd9', 'BABIP', 'LOBp', 'GBp', 'HRdFB15', 'ERA16', 'FIP17', 'xFIP18', 'Age', 'CG', 'ShO', 'H', 'R', 'ER', 'HR', 'BB', 'IBB', 'SO', 'KdBB', 'AVG', 'WHIP', 'FIP49', 'WAR', 'Dollars', 'WPA', 'nWPA', 'pWPA', 'FBv', 'SLp', 'SLv', 'CTp', 'CTv', 'CBp', 'CBv', 'CHp', 'CHv', 'SFp', 'SFv', 'wFB', 'wSL', 'wCT', 'wCB', 'wCH', 'wSF', 'ServiceTime']
print(columns)
df.createOrReplaceTempView("df")

for i in range(6,21):
    subcommand = ""
    for j in range(1,7):
        if(j < 6):
            for column in columns:
                line = ", sum(CASE WHEN ServiceTime = " + str(i-j) + " THEN " + column + " ELSE 0 END) " + str(6-j)+"y"+ column + "\n"
                subcommand += line
        else:
            line = ", sum(CASE WHEN ServiceTime = " + str(i) + " THEN " + "WAR" + " ELSE NULL END) " + "futureWAR"+"\n"
            subcommand += line
        
    command = "SELECT Name, playerid " + subcommand + "FROM df " + "GROUP BY Name, playerid HAVING 1ySeason >= 2002"
    df2 = spark.sql(command)
    df2.createOrReplaceTempView("tmp")
    df2 = spark.sql("SELECT * FROM tmp WHERE futureWAR IS NOT NULL")
    df2.toPandas().to_csv("last5year_" + str(i) + ".csv", header=True)
    print("last5year_" + str(i) + ".csv" + " is dumped.")
# Out:
# ['Season', 'W', 'L', 'G', 'GS', 'IP', 'Kd9', 'BBd9', 'HRd9', 'BABIP', 'LOBp', 'GBp', 'HRdFB15', 'ERA16', 'FIP17', 'xFIP18', 'Age', 'CG', 'ShO', 'H', 'R', 'ER', 'HR', 'BB', 'IBB', 'SO', 'KdBB', 'AVG', 'WHIP', 'FIP49', 'WAR', 'Dollars', 'WPA', 'nWPA', 'pWPA', 'FBv', 'SLp', 'SLv', 'CTp', 'CTv', 'CBp', 'CBv', 'CHp', 'CHv', 'SFp', 'SFv', 'wFB', 'wSL', 'wCT', 'wCB', 'wCH', 'wSF', 'ServiceTime']
# last5year_6.csv is dumped.
# last5year_7.csv is dumped.
# last5year_8.csv is dumped.
# last5year_9.csv is dumped.
# last5year_10.csv is dumped.
# last5year_11.csv is dumped.
# last5year_12.csv is dumped.
# last5year_13.csv is dumped.
# last5year_14.csv is dumped.
# last5year_15.csv is dumped.
# last5year_16.csv is dumped.
# last5year_17.csv is dumped.
# last5year_18.csv is dumped.
# last5year_19.csv is dumped.
# last5year_20.csv is dumped.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master('local[*]').appName('SparkSQL_Review').getOrCreate()
df = spark.read.format("com.databricks.spark.csv").option("header", "true").option("inferSchema", "true").load('D:/OneDrive\OneDrive - postech.ac.kr/2019 Spring/창의설계 3/Archive/real data/Fangraphs 1980-2017 5ys.csv')
df.printSchema()

columns = ['Season', 'W', 'L', 'G', 'GS', 'IP', 'Kd9', 'BBd9', 'HRd9', 'BABIP', 'LOBp', 'GBp', 'HRdFB15', 'ERA16', 'FIP17', 'xFIP18', 'Age', 'CG', 'ShO', 'H', 'R', 'ER', 'HR', 'BB', 'IBB', 'SO', 'KdBB', 'AVG', 'WHIP', 'FIP49', 'WAR', 'Dollars', 'WPA', 'nWPA', 'pWPA', 'FBv', 'SLp', 'SLv', 'CTp', 'CTv', 'CBp', 'CBv', 'CHp', 'CHv', 'SFp', 'SFv', 'wFB', 'wSL', 'wCT', 'wCB', 'wCH', 'wSF', 'ServiceTime']
print(columns)
df.createOrReplaceTempView("df")

for lastyear in range(1,6):
    for i in range(lastyear+1,21):
        subcommand = ""
        for j in range(1,lastyear+2):
            if(j < lastyear+1):
                for column in columns:
                    line = ", sum(CASE WHEN ServiceTime = " + str(i-j) + " THEN " + column + " ELSE 0 END) " + str(lastyear+1-j)+"y"+ column + "\n"
                    subcommand += line
            else:
                line = ", sum(CASE WHEN ServiceTime = " + str(i) + " THEN " + "WAR" + " ELSE NULL END) " + "futureWAR"+"\n"
                subcommand += line

        command = "SELECT Name, playerid " + subcommand + "FROM df " + "GROUP BY Name, playerid HAVING 1ySeason >= 2002"
        df2 = spark.sql(command)
        df2.createOrReplaceTempView("tmp")
        df2 = spark.sql("SELECT * FROM tmp WHERE futureWAR IS NOT NULL")
        df2.toPandas().to_csv("last" + str(lastyear) + "/last" + str(lastyear) + "year_" + str(i) + ".csv", header=True)
        print("last" +  str(lastyear) + "year_" + str(i) + ".csv" + " is dumped.")
# Out:
# root
#  |-- Season: integer (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Team: string (nullable = true)
#  |-- W: integer (nullable = true)
#  |-- L: integer (nullable = true)
#  |-- SV5: integer (nullable = true)
#  |-- G: integer (nullable = true)
#  |-- GS: integer (nullable = true)
#  |-- IP: double (nullable = true)
#  |-- Kd9: double (nullable = true)
#  |-- BBd9: double (nullable = true)
#  |-- HRd9: double (nullable = true)
#  |-- BABIP: double (nullable = true)
#  |-- LOBp: double (nullable = true)
#  |-- GBp: double (nullable = true)
#  |-- HRdFB15: double (nullable = true)
#  |-- ERA16: double (nullable = true)
#  |-- FIP17: double (nullable = true)
#  |-- xFIP18: double (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- ERA20: double (nullable = true)
#  |-- CG: integer (nullable = true)
#  |-- ShO: integer (nullable = true)
#  |-- SV23: integer (nullable = true)
#  |-- TBF: integer (nullable = true)
#  |-- H: integer (nullable = true)
# ...

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master('local[*]').appName('SparkSQL_Review').getOrCreate()
df = spark.read.format("com.databricks.spark.csv").option("header", "true").option("inferSchema", "true").load('D:/OneDrive\OneDrive - postech.ac.kr/2019 Spring/창의설계 3/Archive/real data/Fangraphs 1980-2017 5ys.csv')
df.printSchema()

columns = ['Season', 'IP', 'FIP17', 'Age','SO', 'WAR', 'WPA', 'nWPA', 'pWPA', 'FBv', 'SLp', 'SLv', 'CTp', 'CTv', 'CBp', 'CBv', 'CHp', 'CHv', 'SFp', 'SFv', 'wFB', 'wSL', 'wCT', 'wCB', 'wCH', 'wSF', 'ServiceTime']
print(columns)
df.createOrReplaceTempView("df")

for lastyear in range(1,6):
    for i in range(lastyear+1,21):
        subcommand = ""
        for j in range(1,lastyear+2):
            if(j < lastyear+1):
                for column in columns:
                    line = ", sum(CASE WHEN ServiceTime = " + str(i-j) + " THEN " + column + " ELSE 0 END) " + str(lastyear+1-j)+"y"+ column + "\n"
                    subcommand += line
            else:
                line = ", sum(CASE WHEN ServiceTime = " + str(i) + " THEN " + "WAR" + " ELSE NULL END) " + "futureWAR"+"\n"
                subcommand += line

        command = "SELECT Name, playerid " + subcommand + "FROM df " + "GROUP BY Name, playerid HAVING 1ySeason >= 2002"
        df2 = spark.sql(command)
        df2.createOrReplaceTempView("tmp")
        df2 = spark.sql("SELECT * FROM tmp WHERE futureWAR IS NOT NULL")
        df2.toPandas().to_csv("highcor_last" + str(lastyear) + "/last" + str(lastyear) + "year_" + str(i) + ".csv", header=True)
        print("last" +  str(lastyear) + "year_" + str(i) + ".csv" + " is dumped.")
# Out:
# root
#  |-- Season: integer (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Team: string (nullable = true)
#  |-- W: integer (nullable = true)
#  |-- L: integer (nullable = true)
#  |-- SV5: integer (nullable = true)
#  |-- G: integer (nullable = true)
#  |-- GS: integer (nullable = true)
#  |-- IP: double (nullable = true)
#  |-- Kd9: double (nullable = true)
#  |-- BBd9: double (nullable = true)
#  |-- HRd9: double (nullable = true)
#  |-- BABIP: double (nullable = true)
#  |-- LOBp: double (nullable = true)
#  |-- GBp: double (nullable = true)
#  |-- HRdFB15: double (nullable = true)
#  |-- ERA16: double (nullable = true)
#  |-- FIP17: double (nullable = true)
#  |-- xFIP18: double (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- ERA20: double (nullable = true)
#  |-- CG: integer (nullable = true)
#  |-- ShO: integer (nullable = true)
#  |-- SV23: integer (nullable = true)
#  |-- TBF: integer (nullable = true)
#  |-- H: integer (nullable = true)
# ...
